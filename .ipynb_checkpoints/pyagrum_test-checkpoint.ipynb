# %%
from pylab import *
import matplotlib.pyplot as plt
import os
import pyAgrum as gum
import pyAgrum.lib.notebook as gnb

bn = gum.loadBN('model_summary_media_total.bif')

# gum.config['notebook','potential_visible_digits']=2
# gnb.sideBySide(bn.cpt("Cloudy?"),captions=['$P(Cloudy)$'])
# gnb.sideBySide(
#   gnb.getSideBySide(bn.cpt("Sprinkler?"),captions=['$P(Sprinkler|Cloudy)$']),
bn
#   gnb.getSideBySide(bn.cpt("Rain?"),captions=['$P(Rain|Cloudy)$']))
# gnb.sideBySide(bn.cpt("Wet Grass?"),captions=['$P(WetGrass|Sprinkler,Rain)$'])
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# /var/folders/77/z10lt1sx7mx9rzhbrhk10kcm0000gn/T/ipykernel_69372/1952357917.py in <module>
#       5 import pyAgrum.lib.notebook as gnb
#       6
# ----> 7 bn = gum.loadBN('model_summary_media_total.bif')
#       8
#       9 # gum.config['notebook','potential_visible_digits']=2
#
# /opt/anaconda3/envs/bbn/lib/python3.10/site-packages/pyAgrum/__init__.py in loadBN(filename, listeners, verbose, **opts)
#     185   extension = filename.split('.')[-1].upper()
#     186   if extension == "BIF":
# --> 187     warns = bn.loadBIF(filename, listeners)
#     188   elif extension == "BIFXML":
#     189     warns = bn.loadBIFXML(filename, listeners)
#
# /opt/anaconda3/envs/bbn/lib/python3.10/site-packages/pyAgrum/pyAgrum.py in loadBIF(self, *args)
#    9502
#    9503         """
# -> 9504         return _pyAgrum.BayesNet_loadBIF(self, *args)
#    9505
#    9506     def saveBIF(self, name: str) -> None:
#
# IOError: [pyAgrum] I/O Error: No such file model_summary_media_total.bif
